# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import os.path
import csv
from pathlib import Path
from sqlalchemy import create_engine

# %%
aapl_path = Path("../Data_files/aapl_trends.csv")
amzn_path = Path("../Data_files/amzn_trends.csv")
bac_path = Path("../Data_files/bac_trends.csv")
brk_path = Path("../Data_files/brk_trends.csv")
dis_path = Path("../Data_files/dis_trends.csv")
fb_path = Path("../Data_files/fb_trends.csv")
googl_path = Path("../Data_files/googl_trends.csv")
hd_path = Path("../Data_files/hd_trends.csv")
intc_path = Path("../Data_files/intc_trends.csv")
jnj_path = Path("../Data_files/jnj_trends.csv")
jpm_path = Path("../Data_files/jpm_trends.csv")
ma_path = Path("../Data_files/ma_trends.csv")
msft_path = Path("../Data_files/msft_trends.csv")
pg_path = Path("../Data_files/pg_trends.csv")
t_path = Path("../Data_files/t_trends.csv")
unh_path = Path("../Data_files/unh_trends.csv")
v_path = Path("../Data_files/v_trends.csv")
vz_path = Path("../Data_files/vz_trends.csv")
wmt_path = Path("../Data_files/wmt_trends.csv")
xom_path = Path("../Data_files/xom_trends.csv")

# %%
aapl_trends = pd.read_csv(aapl_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

amzn_trends = pd.read_csv(amzn_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

bac_trends = pd.read_csv(bac_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

brk_trends = pd.read_csv(brk_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

dis_trends = pd.read_csv(dis_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

fb_trends = pd.read_csv(fb_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

googl_trends = pd.read_csv(googl_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

hd_trends = pd.read_csv(hd_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

intc_trends = pd.read_csv(intc_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

jnj_trends = pd.read_csv(jnj_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

jpm_trends = pd.read_csv(jpm_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

ma_trends = pd.read_csv(ma_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

msft_trends = pd.read_csv(msft_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

pg_trends = pd.read_csv(pg_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

t_trends = pd.read_csv(t_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

unh_trends = pd.read_csv(unh_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

v_trends = pd.read_csv(v_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

vz_trends = pd.read_csv(vz_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

wmt_trends = pd.read_csv(wmt_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

xom_trends = pd.read_csv(xom_path, index_col="week",
                          infer_datetime_format=True, 
                          parse_dates=True)

# %%
trends_aapl = pd.Dataframe(aapl_trends)
trends_amzn = pd.DataFrame(amzn_trends)
trends_bac = pd.DataFrame(bac_trends)
# Out:
# AMZN    int64
# dtype: object

# %%
clean_aapl_trends = trends_aapl.groupby(trends_aapl.index).first()
#edit_trends_aapl.shape

# %%
clean_amzn_trends = trends_amzn.groupby(trends_amzn.index).first()
#edit_trends_amzn.shape

# %%
clean_bac_trends = trends_bac.groupby(trends_bac.index).first()
edit_trends_bac.shape
# Out:
# (156, 1)

# %%
clean_brk_trends = brk_trends.groupby(brk_trends.index).first()
clean_brk_trends.shape
# Out:
# (156, 1)

# %%
clean_dis_trends = dis_trends.groupby(dis_trends.index).first()
clean_fb_trends = fb_trends.groupby(fb_trends.index).first()
clean_googl_trends = googl_trends.groupby(googl_trends.index).first()
clean_hd_trends = hd_trends.groupby(hd_trends.index).first()
clean_intc_trends = intc_trends.groupby(intc_trends.index).first()
clean_jnj_trends = jnj_trends.groupby(jnj_trends.index).first()
clean_jpm_trends = jpm_trends.groupby(jpm_trends.index).first()
clean_ma_trends = ma_trends.groupby(ma_trends.index).first()
clean_msft_trends = msft_trends.groupby(msft_trends.index).first()
clean_pg_trends = pg_trends.groupby(pg_trends.index).first()
clean_t_trends = t_trends.groupby(t_trends.index).first()
clean_unh_trends = unh_trends.groupby(unh_trends.index).first()
clean_v_trends = v_trends.groupby(v_trends.index).first()
clean_vz_trends = vz_trends.groupby(vz_trends.index).first()
clean_wmt_trends = wmt_trends.groupby(wmt_trends.index).first()
clean_xom_trends = xom_trends.groupby(xom_trends.index).first()

# %%
#trends = pd.concat([edit_trends_aapl,edit_trends_amzn, edit_brk_trends],axis=1)
#trends
#trends_amzn[1:100]
trends_df = pd.concat([clean_aapl_trends, clean_amzn_trends, clean_bac_trends, clean_brk_trends, clean_dis_trends, clean_fb_trends, clean_googl_trends, clean_hd_trends, clean_intc_trends, clean_jnj_trends, clean_jpm_trends, clean_ma_trends, clean_msft_trends, clean_pg_trends, clean_t_trends, clean_unh_trends, clean_v_trends, clean_vz_trends, clean_wmt_trends, clean_xom_trends], axis=1)
trends_df
# Out:
#             AAPL   AMZN  BRK  BRK  DIS  FB  GOOGL  HD  INTC  JNJ  JPM   MA  \
# week
# 2016-11-13  37.0   28.0   14   14   23  87     82  56    17    4   41   58
# 2016-11-20  48.0   32.0   22   22   22  58     73  49    14    8   22   28
# 2016-11-27  39.0   40.0   17   17   24  55     71  40    20   14   31   28
# 2016-12-04  47.0   29.0   16   16   24  58     82  27    16   10   27   40
# 2016-12-11  39.0   36.0   24   24   14  67     74  28    16   10   37   43
# 2016-12-18  60.0   32.0   16   16   23  63     72  26    15   12   24   13
# 2016-12-25  44.0   48.0   24   24   22  58     65  29    10    7   26   15
# 2017-01-01  39.0   34.0   21   21   21  58     64  31    38    4   39   22
# 2017-01-08  35.0   31.0   24   24   29  58     68  27    18   10   43   21
# 2017-01-15  29.0   27.0   14   14   24  56     71  31    14    5   55   31
# 2017-01-22  42.0   22.0   26   26   16  58     82  45    14   45   23   37
# ...

# %%
engine = create_engine("postgresql://AGalak:RICE-RC-SP-AG@database-1.cvonj9w8tjhh.us-east-2.rds.amazonaws.com:5432/FintechProject2")
trends_df.to_sql('weekly_trends', engine)
